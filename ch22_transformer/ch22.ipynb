# %% [markdown]
# #### https://keras.io/examples/vision/image_classification_with_vision_transformer/

# %%
import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import tensorflow_addons as tfa
# Out:
# 2023-08-24 05:49:07.848563: I tensorflow/core/platform/cpu_feature_guard.cc:183] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: SSE3 SSE4.1 SSE4.2 AVX, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# /usr/local/lib/python3.10/dist-packages/tensorflow_addons/utils/ensure_tf_install.py:53: UserWarning: Tensorflow Addons supports using Python ops for all Tensorflow versions above or equal to 2.9.0 and strictly below 2.12.0 (nightly versions are not supported).
#  The versions of TensorFlow you are currently using is 2.12.0 and is not supported.
# Some things might work, some things might not.
# If you were to encounter a bug, do not file an issue.
# If you want to make sure you're using a tested and supported configuration, either change the TensorFlow version or the TensorFlow Addons's version.
# You can find the compatibility matrix in TensorFlow Addon's readme:
# https://github.com/tensorflow/addons
#   warnings.warn(

# %%
num_classes = 100
input_shape = (32, 32, 3)

(x_train, y_train), (x_test, y_test) = keras.datasets.cifar100.load_data()

print(f"x_train shape: {x_train.shape} - y_train shape: {y_train.shape}")
print(f"x_test shape: {x_test.shape} - y_test shape: {y_test.shape}")
# Out:
# x_train shape: (50000, 32, 32, 3) - y_train shape: (50000, 1)
# x_test shape: (10000, 32, 32, 3) - y_test shape: (10000, 1)

# %%
learning_rate = 0.001
weight_decay = 0.0001
batch_size = 256
num_epochs = 100
image_size = 72  # We'll resize input images to this size
patch_size = 6  # Size of the patches to be extract from the input images
num_patches = (image_size // patch_size) ** 2
projection_dim = 64
num_heads = 4
transformer_units = [
    projection_dim * 2,
    projection_dim,
]  # Size of the transformer layers
transformer_layers = 8
mlp_head_units = [2048, 1024]  # Size of the dense layers of the final classifier

# %%
data_augmentation = keras.Sequential(
    [
        layers.Normalization(),
        layers.Resizing(image_size, image_size),
        layers.RandomFlip("horizontal"),
        layers.RandomRotation(factor=0.02),
        layers.RandomZoom(
            height_factor=0.2, width_factor=0.2
        ),
    ],
    name="data_augmentation",
)
# Compute the mean and the variance of the training data for normalization.
data_augmentation.layers[0].adapt(x_train)
# Out:
# 2023-08-24 05:49:12.097926: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1638] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 38319 MB memory:  -> device: 0, name: NVIDIA A100-SXM4-40GB, pci bus id: 0000:87:00.0, compute capability: 8.0

# %%
def mlp(x, hidden_units, dropout_rate):
    for units in hidden_units:
        x = layers.Dense(units, activation=tf.nn.gelu)(x)
        x = layers.Dropout(dropout_rate)(x)
    return x

# %%
class Patches(layers.Layer):
    def __init__(self, patch_size):
        super().__init__()
        self.patch_size = patch_size

    def call(self, images):
        batch_size = tf.shape(images)[0]
        patches = tf.image.extract_patches(
            images=images,
            sizes=[1, self.patch_size, self.patch_size, 1],
            strides=[1, self.patch_size, self.patch_size, 1],
            rates=[1, 1, 1, 1],
            padding="VALID",
        )
        patch_dims = patches.shape[-1]
        patches = tf.reshape(patches, [batch_size, -1, patch_dims])
        return patches

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(4, 4))
image = x_train[np.random.choice(range(x_train.shape[0]))]
plt.imshow(image.astype("uint8"))
plt.axis("off")

resized_image = tf.image.resize(
    tf.convert_to_tensor([image]), size=(image_size, image_size)
)
patches = Patches(patch_size)(resized_image)
print(f"Image size: {image_size} X {image_size}")
print(f"Patch size: {patch_size} X {patch_size}")
print(f"Patches per image: {patches.shape[1]}")
print(f"Elements per patch: {patches.shape[-1]}")

n = int(np.sqrt(patches.shape[1]))
plt.figure(figsize=(4, 4))
for i, patch in enumerate(patches[0]):
    ax = plt.subplot(n, n, i + 1)
    patch_img = tf.reshape(patch, (patch_size, patch_size, 3))
    plt.imshow(patch_img.numpy().astype("uint8"))
    plt.axis("off")
# Out:
# Image size: 72 X 72
# Patch size: 6 X 6
# Patches per image: 144
# Elements per patch: 108

# %%
class PatchEncoder(layers.Layer):
    def __init__(self, num_patches, projection_dim):
        super().__init__()
        self.num_patches = num_patches
        self.projection = layers.Dense(units=projection_dim)
        self.position_embedding = layers.Embedding(
            input_dim=num_patches, output_dim=projection_dim
        )

    def call(self, patch):
        positions = tf.range(start=0, limit=self.num_patches, delta=1)
        encoded = self.projection(patch) + self.position_embedding(positions)
        return encoded

# %%
def create_vit_classifier():
    inputs = layers.Input(shape=input_shape)
    # Augment data.
    augmented = data_augmentation(inputs)
    # Create patches.
    patches = Patches(patch_size)(augmented)
    # Encode patches.
    encoded_patches = PatchEncoder(num_patches, projection_dim)(patches)

    # Create multiple layers of the Transformer block.
    for _ in range(transformer_layers):
        # Layer normalization 1.
        x1 = layers.LayerNormalization(epsilon=1e-6)(encoded_patches)
        # Create a multi-head attention layer.
        attention_output = layers.MultiHeadAttention(
            num_heads=num_heads, key_dim=projection_dim, dropout=0.1
        )(x1, x1)
        # Skip connection 1.
        x2 = layers.Add()([attention_output, encoded_patches])
        # Layer normalization 2.
        x3 = layers.LayerNormalization(epsilon=1e-6)(x2)
        # MLP.
        x3 = mlp(x3, hidden_units=transformer_units, dropout_rate=0.1)
        # Skip connection 2.
        encoded_patches = layers.Add()([x3, x2])

    # Create a [batch_size, projection_dim] tensor.
    representation = layers.LayerNormalization(epsilon=1e-6)(encoded_patches)
    representation = layers.Flatten()(representation)
    representation = layers.Dropout(0.5)(representation)
    # Add MLP.
    features = mlp(representation, hidden_units=mlp_head_units, dropout_rate=0.5)
    # Classify outputs.
    logits = layers.Dense(num_classes)(features)
    # Create the Keras model.
    model = keras.Model(inputs=inputs, outputs=logits)
    return model

# %%
def run_experiment(model):
    optimizer = tfa.optimizers.AdamW(
        learning_rate=learning_rate, weight_decay=weight_decay
    )

    model.compile(
        optimizer=optimizer,
        loss=keras.losses.SparseCategoricalCrossentropy(from_logits=True),
        metrics=[
            keras.metrics.SparseCategoricalAccuracy(name="accuracy"),
            keras.metrics.SparseTopKCategoricalAccuracy(5, name="top-5-accuracy"),
        ],
    )

    checkpoint_filepath = "/tmp/checkpoint"
    checkpoint_callback = keras.callbacks.ModelCheckpoint(
        checkpoint_filepath,
        monitor="val_accuracy",
        save_best_only=True,
        save_weights_only=True,
    )

    history = model.fit(
        x=x_train,
        y=y_train,
        batch_size=batch_size,
        epochs=num_epochs,
        validation_split=0.1,
        callbacks=[checkpoint_callback],
    )

    model.load_weights(checkpoint_filepath)
    _, accuracy, top_5_accuracy = model.evaluate(x_test, y_test)
    print(f"Test accuracy: {round(accuracy * 100, 2)}%")
    print(f"Test top 5 accuracy: {round(top_5_accuracy * 100, 2)}%")

    return history


vit_classifier = create_vit_classifier()
history = run_experiment(vit_classifier)
# Out:
# Epoch 1/100
#   1/176 [..............................] - ETA: 20:57 - loss: 7.4685 - accuracy: 0.0117 - top-5-accuracy: 0.0703
# 2023-08-24 05:49:26.916451: I tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:655] TensorFloat-32 will be used for the matrix multiplication. This will only be logged once.
# 176/176 [==============================] - 21s 77ms/step - loss: 4.4469 - accuracy: 0.0494 - top-5-accuracy: 0.1700 - val_loss: 3.8471 - val_accuracy: 0.1134 - val_top-5-accuracy: 0.3166
# Epoch 2/100
# 176/176 [==============================] - 13s 72ms/step - loss: 3.8919 - accuracy: 0.1022 - top-5-accuracy: 0.3044 - val_loss: 3.5650 - val_accuracy: 0.1594 - val_top-5-accuracy: 0.4120
# Epoch 3/100
# 176/176 [==============================] - 12s 71ms/step - loss: 3.6508 - accuracy: 0.1372 - top-5-accuracy: 0.3783 - val_loss: 3.3390 - val_accuracy: 0.2028 - val_top-5-accuracy: 0.4682
# Epoch 4/100
# 176/176 [==============================] - 13s 72ms/step - loss: 3.4571 - accuracy: 0.1676 - top-5-accuracy: 0.4363 - val_loss: 3.1773 - val_accuracy: 0.2270 - val_top-5-accuracy: 0.5182
# Epoch 5/100
# 176/176 [==============================] - 12s 71ms/step - loss: 3.2988 - accuracy: 0.1978 - top-5-accuracy: 0.4803 - val_loss: 3.0593 - val_accuracy: 0.2534 - val_top-5-accuracy: 0.5378
# Epoch 6/100
# 176/176 [==============================] - 13s 71ms/step - loss: 3.1417 - accuracy: 0.2266 - top-5-accuracy: 0.5229 - val_loss: 2.8524 - val_accuracy: 0.2928 - val_top-5-accuracy: 0.5862
# Epoch 7/100
# 176/176 [==============================] - 13s 71ms/step - loss: 3.0108 - accuracy: 0.2501 - top-5-accuracy: 0.5543 - val_loss: 2.7235 - val_accuracy: 0.3150 - val_top-5-accuracy: 0.6202
# Epoch 8/100
# 176/176 [==============================] - 12s 70ms/step - loss: 2.8856 - accuracy: 0.2760 - top-5-accuracy: 0.5840 - val_loss: 2.6532 - val_accuracy: 0.3328 - val_top-5-accuracy: 0.6380
# Epoch 9/100
# 176/176 [==============================] - 12s 71ms/step - loss: 2.7801 - accuracy: 0.2975 - top-5-accuracy: 0.6067 - val_loss: 2.5561 - val_accuracy: 0.3520 - val_top-5-accuracy: 0.6578
# Epoch 10/100
# 176/176 [==============================] - 12s 70ms/step - loss: 2.6827 - accuracy: 0.3171 - top-5-accuracy: 0.6321 - val_loss: 2.4606 - val_accuracy: 0.3698 - val_top-5-accuracy: 0.6792
# Epoch 11/100
# 176/176 [==============================] - 13s 71ms/step - loss: 2.5794 - accuracy: 0.3408 - top-5-accuracy: 0.6537 - val_loss: 2.3873 - val_accuracy: 0.3902 - val_top-5-accuracy: 0.6948
# Epoch 12/100
# 176/176 [==============================] - 12s 71ms/step - loss: 2.5092 - accuracy: 0.3522 - top-5-accuracy: 0.6690 - val_loss: 2.3336 - val_accuracy: 0.3982 - val_top-5-accuracy: 0.7020
# Epoch 13/100
# 176/176 [==============================] - 12s 70ms/step - loss: 2.4175 - accuracy: 0.3732 - top-5-accuracy: 0.6906 - val_loss: 2.2810 - val_accuracy: 0.4022 - val_top-5-accuracy: 0.7100
# Epoch 14/100
# 176/176 [==============================] - 12s 71ms/step - loss: 2.3526 - accuracy: 0.3843 - top-5-accuracy: 0.7043 - val_loss: 2.2141 - val_accuracy: 0.4318 - val_top-5-accuracy: 0.7250
# Epoch 15/100
# 176/176 [==============================] - 12s 68ms/step - loss: 2.2924 - accuracy: 0.3985 - top-5-accuracy: 0.7165 - val_loss: 2.1925 - val_accuracy: 0.4272 - val_top-5-accuracy: 0.7320
# Epoch 16/100
# 176/176 [==============================] - 12s 68ms/step - loss: 2.2223 - accuracy: 0.4122 - top-5-accuracy: 0.7320 - val_loss: 2.1564 - val_accuracy: 0.4310 - val_top-5-accuracy: 0.7386
# Epoch 17/100
# 176/176 [==============================] - 12s 71ms/step - loss: 2.1584 - accuracy: 0.4280 - top-5-accuracy: 0.7448 - val_loss: 2.1383 - val_accuracy: 0.4424 - val_top-5-accuracy: 0.7468
# Epoch 18/100
# 176/176 [==============================] - 12s 71ms/step - loss: 2.0955 - accuracy: 0.4396 - top-5-accuracy: 0.7550 - val_loss: 2.1019 - val_accuracy: 0.4520 - val_top-5-accuracy: 0.7446
# Epoch 19/100
# 176/176 [==============================] - 13s 75ms/step - loss: 2.0355 - accuracy: 0.4527 - top-5-accuracy: 0.7664 - val_loss: 2.0298 - val_accuracy: 0.4640 - val_top-5-accuracy: 0.7638
# Epoch 20/100
# 176/176 [==============================] - 12s 70ms/step - loss: 1.9828 - accuracy: 0.4662 - top-5-accuracy: 0.7770 - val_loss: 2.0156 - val_accuracy: 0.4714 - val_top-5-accuracy: 0.7650
# Epoch 21/100
# 176/176 [==============================] - 13s 71ms/step - loss: 1.9326 - accuracy: 0.4750 - top-5-accuracy: 0.7869 - val_loss: 1.9965 - val_accuracy: 0.4740 - val_top-5-accuracy: 0.7666
# Epoch 22/100
# 176/176 [==============================] - 12s 68ms/step - loss: 1.8892 - accuracy: 0.4832 - top-5-accuracy: 0.7965 - val_loss: 1.9712 - val_accuracy: 0.4672 - val_top-5-accuracy: 0.7760
# Epoch 23/100
# 176/176 [==============================] - 13s 72ms/step - loss: 1.8564 - accuracy: 0.4923 - top-5-accuracy: 0.8020 - val_loss: 1.9527 - val_accuracy: 0.4858 - val_top-5-accuracy: 0.7776
# Epoch 24/100
# 176/176 [==============================] - 12s 68ms/step - loss: 1.8024 - accuracy: 0.5066 - top-5-accuracy: 0.8122 - val_loss: 1.9565 - val_accuracy: 0.4750 - val_top-5-accuracy: 0.7750
# Epoch 25/100
# 176/176 [==============================] - 14s 78ms/step - loss: 1.7513 - accuracy: 0.5186 - top-5-accuracy: 0.8207 - val_loss: 1.9326 - val_accuracy: 0.4876 - val_top-5-accuracy: 0.7808
# Epoch 26/100
# 176/176 [==============================] - 13s 71ms/step - loss: 1.7286 - accuracy: 0.5210 - top-5-accuracy: 0.8260 - val_loss: 1.9006 - val_accuracy: 0.4924 - val_top-5-accuracy: 0.7876
# Epoch 27/100
# 176/176 [==============================] - 12s 69ms/step - loss: 1.6778 - accuracy: 0.5314 - top-5-accuracy: 0.8361 - val_loss: 1.9375 - val_accuracy: 0.4760 - val_top-5-accuracy: 0.7832
# Epoch 28/100
# 176/176 [==============================] - 12s 71ms/step - loss: 1.6419 - accuracy: 0.5402 - top-5-accuracy: 0.8405 - val_loss: 1.8851 - val_accuracy: 0.5024 - val_top-5-accuracy: 0.7880
# Epoch 29/100
# 176/176 [==============================] - 12s 71ms/step - loss: 1.6130 - accuracy: 0.5482 - top-5-accuracy: 0.8474 - val_loss: 1.8764 - val_accuracy: 0.5060 - val_top-5-accuracy: 0.7934
# Epoch 30/100
# 176/176 [==============================] - 12s 67ms/step - loss: 1.5752 - accuracy: 0.5583 - top-5-accuracy: 0.8505 - val_loss: 1.8775 - val_accuracy: 0.5000 - val_top-5-accuracy: 0.7898
# Epoch 31/100
# 176/176 [==============================] - 13s 72ms/step - loss: 1.5490 - accuracy: 0.5636 - top-5-accuracy: 0.8556 - val_loss: 1.8800 - val_accuracy: 0.5094 - val_top-5-accuracy: 0.7944
# Epoch 32/100
# 176/176 [==============================] - 12s 71ms/step - loss: 1.5010 - accuracy: 0.5745 - top-5-accuracy: 0.8633 - val_loss: 1.8687 - val_accuracy: 0.5096 - val_top-5-accuracy: 0.7946
# Epoch 33/100
# 176/176 [==============================] - 12s 70ms/step - loss: 1.4751 - accuracy: 0.5823 - top-5-accuracy: 0.8692 - val_loss: 1.8410 - val_accuracy: 0.5092 - val_top-5-accuracy: 0.8014
# Epoch 34/100
# 176/176 [==============================] - 12s 70ms/step - loss: 1.4472 - accuracy: 0.5895 - top-5-accuracy: 0.8718 - val_loss: 1.8408 - val_accuracy: 0.5192 - val_top-5-accuracy: 0.8034
# Epoch 35/100
# 176/176 [==============================] - 12s 68ms/step - loss: 1.4141 - accuracy: 0.5964 - top-5-accuracy: 0.8777 - val_loss: 1.8602 - val_accuracy: 0.5172 - val_top-5-accuracy: 0.7942
# Epoch 36/100
# 176/176 [==============================] - 12s 68ms/step - loss: 1.3985 - accuracy: 0.6019 - top-5-accuracy: 0.8810 - val_loss: 1.8658 - val_accuracy: 0.5112 - val_top-5-accuracy: 0.8022
# Epoch 37/100
# 176/176 [==============================] - 12s 67ms/step - loss: 1.3837 - accuracy: 0.6030 - top-5-accuracy: 0.8816 - val_loss: 1.8552 - val_accuracy: 0.5170 - val_top-5-accuracy: 0.7974
# Epoch 38/100
# 176/176 [==============================] - 12s 68ms/step - loss: 1.3483 - accuracy: 0.6140 - top-5-accuracy: 0.8873 - val_loss: 1.8598 - val_accuracy: 0.5158 - val_top-5-accuracy: 0.7982
# Epoch 39/100
# 176/176 [==============================] - 13s 72ms/step - loss: 1.3416 - accuracy: 0.6143 - top-5-accuracy: 0.8913 - val_loss: 1.8440 - val_accuracy: 0.5208 - val_top-5-accuracy: 0.8012
# Epoch 40/100
# 176/176 [==============================] - 12s 68ms/step - loss: 1.3037 - accuracy: 0.6230 - top-5-accuracy: 0.8956 - val_loss: 1.8554 - val_accuracy: 0.5156 - val_top-5-accuracy: 0.8050
# Epoch 41/100
# 176/176 [==============================] - 13s 71ms/step - loss: 1.2811 - accuracy: 0.6285 - top-5-accuracy: 0.8980 - val_loss: 1.8377 - val_accuracy: 0.5256 - val_top-5-accuracy: 0.8080
# Epoch 42/100
# 176/176 [==============================] - 12s 70ms/step - loss: 1.2669 - accuracy: 0.6338 - top-5-accuracy: 0.9010 - val_loss: 1.8363 - val_accuracy: 0.5244 - val_top-5-accuracy: 0.8104
# Epoch 43/100
# 176/176 [==============================] - 12s 68ms/step - loss: 1.2516 - accuracy: 0.6392 - top-5-accuracy: 0.9040 - val_loss: 1.8516 - val_accuracy: 0.5178 - val_top-5-accuracy: 0.8026
# Epoch 44/100
# 176/176 [==============================] - 12s 71ms/step - loss: 1.2118 - accuracy: 0.6482 - top-5-accuracy: 0.9080 - val_loss: 1.8303 - val_accuracy: 0.5342 - val_top-5-accuracy: 0.8150
# Epoch 45/100
# 176/176 [==============================] - 12s 71ms/step - loss: 1.2017 - accuracy: 0.6482 - top-5-accuracy: 0.9096 - val_loss: 1.8114 - val_accuracy: 0.5350 - val_top-5-accuracy: 0.8086
# Epoch 46/100
# 176/176 [==============================] - 12s 68ms/step - loss: 1.1866 - accuracy: 0.6551 - top-5-accuracy: 0.9113 - val_loss: 1.8294 - val_accuracy: 0.5286 - val_top-5-accuracy: 0.8108
# Epoch 47/100
# 176/176 [==============================] - 12s 70ms/step - loss: 1.1609 - accuracy: 0.6600 - top-5-accuracy: 0.9154 - val_loss: 1.8552 - val_accuracy: 0.5290 - val_top-5-accuracy: 0.8100
# Epoch 48/100
# 176/176 [==============================] - 12s 68ms/step - loss: 1.1488 - accuracy: 0.6605 - top-5-accuracy: 0.9167 - val_loss: 1.8430 - val_accuracy: 0.5276 - val_top-5-accuracy: 0.8076
# Epoch 49/100
# 176/176 [==============================] - 13s 73ms/step - loss: 1.1498 - accuracy: 0.6611 - top-5-accuracy: 0.9166 - val_loss: 1.8342 - val_accuracy: 0.5236 - val_top-5-accuracy: 0.8068
# Epoch 50/100
# 176/176 [==============================] - 12s 68ms/step - loss: 1.1204 - accuracy: 0.6700 - top-5-accuracy: 0.9208 - val_loss: 1.8431 - val_accuracy: 0.5282 - val_top-5-accuracy: 0.8088
# Epoch 51/100
# 176/176 [==============================] - 13s 72ms/step - loss: 1.1181 - accuracy: 0.6716 - top-5-accuracy: 0.9216 - val_loss: 1.8275 - val_accuracy: 0.5300 - val_top-5-accuracy: 0.8114
# Epoch 52/100
# 176/176 [==============================] - 12s 68ms/step - loss: 1.0895 - accuracy: 0.6776 - top-5-accuracy: 0.9270 - val_loss: 1.8356 - val_accuracy: 0.5348 - val_top-5-accuracy: 0.8146
# Epoch 53/100
# 176/176 [==============================] - 12s 68ms/step - loss: 1.0896 - accuracy: 0.6806 - top-5-accuracy: 0.9260 - val_loss: 1.8334 - val_accuracy: 0.5314 - val_top-5-accuracy: 0.8058
# Epoch 54/100
# 176/176 [==============================] - 12s 68ms/step - loss: 1.0788 - accuracy: 0.6847 - top-5-accuracy: 0.9256 - val_loss: 1.8429 - val_accuracy: 0.5348 - val_top-5-accuracy: 0.8116
# Epoch 55/100
# 176/176 [==============================] - 12s 70ms/step - loss: 1.0523 - accuracy: 0.6876 - top-5-accuracy: 0.9301 - val_loss: 1.8440 - val_accuracy: 0.5362 - val_top-5-accuracy: 0.8102
# Epoch 56/100
# 176/176 [==============================] - 12s 68ms/step - loss: 1.0389 - accuracy: 0.6919 - top-5-accuracy: 0.9315 - val_loss: 1.8511 - val_accuracy: 0.5318 - val_top-5-accuracy: 0.8094
# Epoch 57/100
# 176/176 [==============================] - 12s 67ms/step - loss: 1.0170 - accuracy: 0.6970 - top-5-accuracy: 0.9350 - val_loss: 1.8665 - val_accuracy: 0.5300 - val_top-5-accuracy: 0.8074
# Epoch 58/100
# 176/176 [==============================] - 13s 72ms/step - loss: 1.0153 - accuracy: 0.6998 - top-5-accuracy: 0.9363 - val_loss: 1.8523 - val_accuracy: 0.5372 - val_top-5-accuracy: 0.8122
# Epoch 59/100
# 176/176 [==============================] - 13s 71ms/step - loss: 1.0002 - accuracy: 0.7029 - top-5-accuracy: 0.9378 - val_loss: 1.8452 - val_accuracy: 0.5386 - val_top-5-accuracy: 0.8076
# Epoch 60/100
# 176/176 [==============================] - 13s 75ms/step - loss: 0.9940 - accuracy: 0.7040 - top-5-accuracy: 0.9374 - val_loss: 1.8629 - val_accuracy: 0.5350 - val_top-5-accuracy: 0.8104
# Epoch 61/100
# 176/176 [==============================] - 12s 67ms/step - loss: 0.9816 - accuracy: 0.7094 - top-5-accuracy: 0.9396 - val_loss: 1.8546 - val_accuracy: 0.5324 - val_top-5-accuracy: 0.8094
# Epoch 62/100
# 176/176 [==============================] - 12s 68ms/step - loss: 0.9757 - accuracy: 0.7090 - top-5-accuracy: 0.9399 - val_loss: 1.8871 - val_accuracy: 0.5248 - val_top-5-accuracy: 0.8078
# Epoch 63/100
# 176/176 [==============================] - 12s 68ms/step - loss: 0.9651 - accuracy: 0.7138 - top-5-accuracy: 0.9391 - val_loss: 1.8671 - val_accuracy: 0.5360 - val_top-5-accuracy: 0.8096
# Epoch 64/100
# 176/176 [==============================] - 13s 71ms/step - loss: 0.9623 - accuracy: 0.7133 - top-5-accuracy: 0.9429 - val_loss: 1.8794 - val_accuracy: 0.5388 - val_top-5-accuracy: 0.8136
# Epoch 65/100
# 176/176 [==============================] - 12s 71ms/step - loss: 0.9482 - accuracy: 0.7150 - top-5-accuracy: 0.9436 - val_loss: 1.8743 - val_accuracy: 0.5426 - val_top-5-accuracy: 0.8146
# Epoch 66/100
# 176/176 [==============================] - 12s 67ms/step - loss: 0.9379 - accuracy: 0.7180 - top-5-accuracy: 0.9444 - val_loss: 1.8695 - val_accuracy: 0.5368 - val_top-5-accuracy: 0.8126
# Epoch 67/100
# 176/176 [==============================] - 12s 69ms/step - loss: 0.9297 - accuracy: 0.7227 - top-5-accuracy: 0.9440 - val_loss: 1.8478 - val_accuracy: 0.5338 - val_top-5-accuracy: 0.8186
# Epoch 68/100
# 176/176 [==============================] - 12s 68ms/step - loss: 0.9180 - accuracy: 0.7269 - top-5-accuracy: 0.9456 - val_loss: 1.8834 - val_accuracy: 0.5396 - val_top-5-accuracy: 0.8140
# Epoch 69/100
# 176/176 [==============================] - 12s 70ms/step - loss: 0.9093 - accuracy: 0.7277 - top-5-accuracy: 0.9473 - val_loss: 1.8752 - val_accuracy: 0.5358 - val_top-5-accuracy: 0.8142
# Epoch 70/100
# 176/176 [==============================] - 12s 71ms/step - loss: 0.9038 - accuracy: 0.7298 - top-5-accuracy: 0.9473 - val_loss: 1.8673 - val_accuracy: 0.5436 - val_top-5-accuracy: 0.8114
# Epoch 71/100
# 176/176 [==============================] - 13s 72ms/step - loss: 0.9070 - accuracy: 0.7295 - top-5-accuracy: 0.9475 - val_loss: 1.8655 - val_accuracy: 0.5450 - val_top-5-accuracy: 0.8122
# Epoch 72/100
# 176/176 [==============================] - 12s 68ms/step - loss: 0.8862 - accuracy: 0.7355 - top-5-accuracy: 0.9495 - val_loss: 1.8902 - val_accuracy: 0.5314 - val_top-5-accuracy: 0.8140
# Epoch 73/100
# 176/176 [==============================] - 12s 67ms/step - loss: 0.8800 - accuracy: 0.7354 - top-5-accuracy: 0.9503 - val_loss: 1.8786 - val_accuracy: 0.5394 - val_top-5-accuracy: 0.8164
# Epoch 74/100
# 176/176 [==============================] - 12s 68ms/step - loss: 0.8730 - accuracy: 0.7364 - top-5-accuracy: 0.9505 - val_loss: 1.8736 - val_accuracy: 0.5330 - val_top-5-accuracy: 0.8158
# Epoch 75/100
# 176/176 [==============================] - 12s 68ms/step - loss: 0.8746 - accuracy: 0.7378 - top-5-accuracy: 0.9510 - val_loss: 1.9052 - val_accuracy: 0.5338 - val_top-5-accuracy: 0.8082
# Epoch 76/100
# 176/176 [==============================] - 13s 74ms/step - loss: 0.8732 - accuracy: 0.7411 - top-5-accuracy: 0.9509 - val_loss: 1.8670 - val_accuracy: 0.5442 - val_top-5-accuracy: 0.8124
# Epoch 77/100
# 176/176 [==============================] - 12s 67ms/step - loss: 0.8682 - accuracy: 0.7413 - top-5-accuracy: 0.9504 - val_loss: 1.8867 - val_accuracy: 0.5432 - val_top-5-accuracy: 0.8142
# Epoch 78/100
# 176/176 [==============================] - 12s 71ms/step - loss: 0.8432 - accuracy: 0.7466 - top-5-accuracy: 0.9556 - val_loss: 1.9095 - val_accuracy: 0.5356 - val_top-5-accuracy: 0.8100
# Epoch 79/100
# 176/176 [==============================] - 12s 67ms/step - loss: 0.8526 - accuracy: 0.7435 - top-5-accuracy: 0.9538 - val_loss: 1.8721 - val_accuracy: 0.5422 - val_top-5-accuracy: 0.8072
# Epoch 80/100
# 176/176 [==============================] - 12s 68ms/step - loss: 0.8560 - accuracy: 0.7438 - top-5-accuracy: 0.9527 - val_loss: 1.8740 - val_accuracy: 0.5444 - val_top-5-accuracy: 0.8058
# Epoch 81/100
# 176/176 [==============================] - 12s 68ms/step - loss: 0.8481 - accuracy: 0.7460 - top-5-accuracy: 0.9539 - val_loss: 1.9242 - val_accuracy: 0.5406 - val_top-5-accuracy: 0.8054
# Epoch 82/100
# 176/176 [==============================] - 12s 68ms/step - loss: 0.8381 - accuracy: 0.7487 - top-5-accuracy: 0.9553 - val_loss: 1.8991 - val_accuracy: 0.5444 - val_top-5-accuracy: 0.8112
# Epoch 83/100
# 176/176 [==============================] - 12s 71ms/step - loss: 0.8366 - accuracy: 0.7496 - top-5-accuracy: 0.9548 - val_loss: 1.8500 - val_accuracy: 0.5454 - val_top-5-accuracy: 0.8154
# Epoch 84/100
# 176/176 [==============================] - 13s 71ms/step - loss: 0.8176 - accuracy: 0.7524 - top-5-accuracy: 0.9561 - val_loss: 1.8688 - val_accuracy: 0.5524 - val_top-5-accuracy: 0.8152
# Epoch 85/100
# 176/176 [==============================] - 12s 68ms/step - loss: 0.8236 - accuracy: 0.7529 - top-5-accuracy: 0.9562 - val_loss: 1.8532 - val_accuracy: 0.5498 - val_top-5-accuracy: 0.8150
# Epoch 86/100
# 176/176 [==============================] - 12s 68ms/step - loss: 0.8100 - accuracy: 0.7567 - top-5-accuracy: 0.9576 - val_loss: 1.8952 - val_accuracy: 0.5428 - val_top-5-accuracy: 0.8096
# Epoch 87/100
# 176/176 [==============================] - 12s 68ms/step - loss: 0.8017 - accuracy: 0.7606 - top-5-accuracy: 0.9581 - val_loss: 1.9172 - val_accuracy: 0.5438 - val_top-5-accuracy: 0.8130
# Epoch 88/100
# 176/176 [==============================] - 13s 73ms/step - loss: 0.8096 - accuracy: 0.7576 - top-5-accuracy: 0.9563 - val_loss: 1.9178 - val_accuracy: 0.5418 - val_top-5-accuracy: 0.8086
# Epoch 89/100
# 176/176 [==============================] - 12s 67ms/step - loss: 0.8061 - accuracy: 0.7579 - top-5-accuracy: 0.9572 - val_loss: 1.9049 - val_accuracy: 0.5484 - val_top-5-accuracy: 0.8078
# Epoch 90/100
# 176/176 [==============================] - 12s 70ms/step - loss: 0.7941 - accuracy: 0.7611 - top-5-accuracy: 0.9575 - val_loss: 1.8991 - val_accuracy: 0.5464 - val_top-5-accuracy: 0.8148
# Epoch 91/100
# 176/176 [==============================] - 12s 67ms/step - loss: 0.7827 - accuracy: 0.7644 - top-5-accuracy: 0.9602 - val_loss: 1.8615 - val_accuracy: 0.5524 - val_top-5-accuracy: 0.8132
# Epoch 92/100
# 176/176 [==============================] - 12s 69ms/step - loss: 0.7876 - accuracy: 0.7646 - top-5-accuracy: 0.9577 - val_loss: 1.9388 - val_accuracy: 0.5376 - val_top-5-accuracy: 0.8138
# Epoch 93/100
# 176/176 [==============================] - 12s 68ms/step - loss: 0.7822 - accuracy: 0.7632 - top-5-accuracy: 0.9603 - val_loss: 1.8778 - val_accuracy: 0.5478 - val_top-5-accuracy: 0.8166
# Epoch 94/100
# 176/176 [==============================] - 12s 68ms/step - loss: 0.7804 - accuracy: 0.7639 - top-5-accuracy: 0.9607 - val_loss: 1.8845 - val_accuracy: 0.5520 - val_top-5-accuracy: 0.8170
# Epoch 95/100
# 176/176 [==============================] - 12s 69ms/step - loss: 0.7827 - accuracy: 0.7637 - top-5-accuracy: 0.9605 - val_loss: 1.8710 - val_accuracy: 0.5504 - val_top-5-accuracy: 0.8104
# Epoch 96/100
# 176/176 [==============================] - 12s 68ms/step - loss: 0.7738 - accuracy: 0.7670 - top-5-accuracy: 0.9606 - val_loss: 1.8697 - val_accuracy: 0.5468 - val_top-5-accuracy: 0.8176
# Epoch 97/100
# 176/176 [==============================] - 12s 68ms/step - loss: 0.7751 - accuracy: 0.7681 - top-5-accuracy: 0.9600 - val_loss: 1.8982 - val_accuracy: 0.5430 - val_top-5-accuracy: 0.8104
# Epoch 98/100
# 176/176 [==============================] - 12s 68ms/step - loss: 0.7661 - accuracy: 0.7680 - top-5-accuracy: 0.9622 - val_loss: 1.8734 - val_accuracy: 0.5404 - val_top-5-accuracy: 0.8116
# Epoch 99/100
# 176/176 [==============================] - 12s 68ms/step - loss: 0.7537 - accuracy: 0.7724 - top-5-accuracy: 0.9620 - val_loss: 1.8873 - val_accuracy: 0.5514 - val_top-5-accuracy: 0.8178
# Epoch 100/100
# 176/176 [==============================] - 12s 68ms/step - loss: 0.7653 - accuracy: 0.7691 - top-5-accuracy: 0.9617 - val_loss: 1.9247 - val_accuracy: 0.5396 - val_top-5-accuracy: 0.8166
# 313/313 [==============================] - 3s 9ms/step - loss: 1.8232 - accuracy: 0.5499 - top-5-accuracy: 0.8179
# Test accuracy: 54.99%
# Test top 5 accuracy: 81.79%
